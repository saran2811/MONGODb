# %% [markdown]
# <a href="https://colab.research.google.com/github/saran2811/MONGODb/blob/main/mongo_flim_task.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from pymongo import MongoClient
import pandas as pd

# %%
saran=MongoClient("mongodb://saranraj:Hulk1997@ac-0c0n4vt-shard-00-00.olc1fqw.mongodb.net:27017,ac-0c0n4vt-shard-00-01.olc1fqw.mongodb.net:27017,ac-0c0n4vt-shard-00-02.olc1fqw.mongodb.net:27017/?ssl=true&replicaSet=atlas-ybjk4f-shard-0&authSource=admin&retryWrites=true&w=majority")

# %%
l=saran["sample_mflix"]

# %%
s=l['movies']

# %%
f=[]
for i in s.find({'$or':[{'$and':[{'year':{'$gte':1950,'$lte':1970}},{'tomatoes.viewer.rating':{'$gt':3}},{'imdb.rating':{'$gt':7}}, {'awards.wins':{'$gte':1}},
                         {'genres':{'$in':['Comedy','Horror','Fantasy']}}]} ,{'$and':[{'year':{'$gte':2000,'$lte':2015}},{'tomatoes.viewer.rating':{'$gt':3}},{'imdb.rating':{'$gt':7}}, {'awards.wins':{'$gte':1}},
                         {'genres':{'$in':['Comedy','Horror','Fantasy']}}]}]},{'_id':0,'title':1,' music director name':1,'directors':1,'cast':1,'imdb.rating':1,'tomatoes.viewer.rating':1,'year':1}):
     f.append(i)

# %%
pd.DataFrame(f)
# Out:
#                                                   cast  \
# 0    [Judy Holliday, Broderick Crawford, William Ho...
# 1       [Aldo Fabrizi, Totè, Ave Ninchi, Pina Piovani]
# 2    [Gene Tierney, John Lund, Miriam Hopkins, Thel...
# 3    [Maria Fiore, Vincenzo Musolino, Filomena Russ...
# 4    [Michael Redgrave, Richard Wattis, Michael Den...
# ..                                                 ...
# 983  [Elyas M'Barek, Karoline Herfurth, Katja Riema...
# 984  [Michael Galante, Michelle Hendley, Jean Dever...
# 985  [Seija Airamo, Erkki Broman, Pirjo Mutanen, Ma...
# 986  [Sam Kantor, Caitlin McConkey-Pirie, Nina Iord...
# 987  [Maz Jobrani, John Heard, Deanna Russo, Marsha...
#
#                                title                            directors  \
# 0                     Born Yesterday                       [George Cukor]
# 1                   Cops and Robbers             [Mario Monicelli, Steno]
# 2                  The Mating Season                    [Mitchell Leisen]
# ...
